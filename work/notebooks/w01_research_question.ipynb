# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulahadshaikhhh-blip/Flyrank-ML-Intern/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Freestyle
# Why: I want to apply machine learning to discover patterns in the warehouse data and build a predictive model. My focus will be on creating meaningful features, performing exploratory data analysis, and training a model to predict content growth or discoverability while avoiding data leakage. This allows me to explore real-world ML techniques such as feature engineering, model evaluation, and performance optimization.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# Decision: My work helps content and SEO teams decide which pages should be prioritized for updates to maximize future traffic and discoverability.
# Who acts on it: SEO specialists, content strategists, and marketing managers use the recommendations to plan content refreshes and allocate resources.
# Cost of a wrong recommendation: A wrong recommendation can waste time and budget by focusing on low-impact pages while overlooking pages with high growth potential. This may lead to lost organic traffic, lower search visibility, and missed business opportunities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
# The dataset contains 12,846 pages. About 31.4% of pages experienced traffic growth over the analysis period, while 18.7% showed significant declines. The average CTR is 3.9%, suggesting there is substantial opportunity to improve discoverability through better content optimization. These findings make this project valuable because it can help identify high-impact pages for optimization over the next seven weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# My work will provide decision-support, not certainty. It will identify patterns and relationships in the data, rank pages based on their likelihood of benefiting from a refresh, and provide evidence-based recommendations for prioritization. The findings will be observational and directional, helping teams make more informed content decisions.
#
# My work will not provide causal proof. It will not claim that any specific factor directly causes higher rankings, nor will it attempt to "predict Google" or reverse-engineer search algorithms. Recommendations will be based on historical data and statistical patterns, not guarantees of future search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
